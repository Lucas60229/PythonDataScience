# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucas60229/PythonDataScience/blob/main/%EF%BC%A418.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 3 * np.pi, 0.1)
y_cos = np.cos(x)
plt.plot(x,y_cos)
# plt.show
plt.savefig("filename.png",dpi=300,format="png")

# %%
scatter_X = np.random.normal(0, 1, 1024)
scatter_Y = np.random.normal(0, 1, 1024)
plt.scatter(scatter_X, scatter_Y, c=scatter_Y)
plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)
plt.show()
